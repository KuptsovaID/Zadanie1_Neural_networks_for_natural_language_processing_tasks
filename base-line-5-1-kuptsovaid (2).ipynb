# %% [markdown]
# # Плотное векторное представление слов для определения тональности текста отзывов на фильмы из IMDb (Internet Movie Database)
#
# Учебный курс "[Нейросети для анализа текстов](https://www.asozykin.ru/courses/nnpython)".

# %%
from tensorflow.keras.datasets import imdb
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, Flatten, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import utils
from tensorflow.keras.preprocessing.sequence import pad_sequences
# работа с обратной связью от обучающейся нейронной сети
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline 
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/dl-urfu-imdb/train.npy
# /kaggle/input/dl-urfu-imdb/train_label.npy
# /kaggle/input/dl-urfu-imdb/sample_supmission.csv
# /kaggle/input/dl-urfu-imdb/test.npy

# %% [markdown]
# Загружаем данные

# %%
KAGGLE_PATH = '/kaggle/input/dl-urfu-imdb/'
x_train = np.load(KAGGLE_PATH + 'train.npy', allow_pickle=True)
y_train = np.load(KAGGLE_PATH + 'train_label.npy', allow_pickle=True)
x_test = np.load(KAGGLE_PATH + 'test.npy', allow_pickle=True)
x_train.shape, y_train.shape, x_test.shape,
# Out:
# ((46000,), (46000,), (4000,))

# %% [markdown]
# ## Подготовка данных для обучения

# %%
max_words = 10_000
maxlen = 250
x_train = pad_sequences(x_train, maxlen=maxlen, padding='post')
x_test = pad_sequences(x_test, maxlen=maxlen, padding='post')

# %% [markdown]
# ## Создание нейронной сети

# %%
model = Sequential()
model.add(Embedding(max_words, 7, input_length=maxlen))
model.add(Dropout(0.8))
model.add(Flatten())
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(optimizer='adam', 
              loss='binary_crossentropy', 
              metrics=['accuracy'])

# %% [markdown]
# ## Обучаем нейронную сеть

# %%
history = model.fit(x_train, 
                    y_train, 
                    epochs=20,
                    batch_size=200,
                    validation_split=0.1)
# Out:
# Epoch 1/20
# 207/207 [==============================] - 2s 8ms/step - loss: 0.6930 - accuracy: 0.5064 - val_loss: 0.6711 - val_accuracy: 0.6643
# Epoch 2/20
# 207/207 [==============================] - 1s 7ms/step - loss: 0.6267 - accuracy: 0.6974 - val_loss: 0.4507 - val_accuracy: 0.8341
# Epoch 3/20
# 207/207 [==============================] - 1s 7ms/step - loss: 0.4332 - accuracy: 0.8199 - val_loss: 0.3390 - val_accuracy: 0.8791
# Epoch 4/20
# 207/207 [==============================] - 1s 7ms/step - loss: 0.3521 - accuracy: 0.8565 - val_loss: 0.2989 - val_accuracy: 0.8898
# Epoch 5/20
# 207/207 [==============================] - 1s 7ms/step - loss: 0.3192 - accuracy: 0.8684 - val_loss: 0.2807 - val_accuracy: 0.8933
# Epoch 6/20
# 207/207 [==============================] - 1s 7ms/step - loss: 0.2954 - accuracy: 0.8773 - val_loss: 0.2678 - val_accuracy: 0.8970
# Epoch 7/20
# 207/207 [==============================] - 1s 7ms/step - loss: 0.2825 - accuracy: 0.8846 - val_loss: 0.2606 - val_accuracy: 0.8991
# Epoch 8/20
# 207/207 [==============================] - 1s 7ms/step - loss: 0.2686 - accuracy: 0.8935 - val_loss: 0.2558 - val_accuracy: 0.8959
# Epoch 9/20
# 207/207 [==============================] - 1s 7ms/step - loss: 0.2617 - accuracy: 0.8941 - val_loss: 0.2546 - val_accuracy: 0.8983
# Epoch 10/20
# 207/207 [==============================] - 1s 7ms/step - loss: 0.2637 - accuracy: 0.8924 - val_loss: 0.2523 - val_accuracy: 0.8976
# Epoch 11/20
# 207/207 [==============================] - 1s 7ms/step - loss: 0.2555 - accuracy: 0.8942 - val_loss: 0.2558 - val_accuracy: 0.8970
# Epoch 12/20
# 207/207 [==============================] - 1s 7ms/step - loss: 0.2580 - accuracy: 0.8947 - val_loss: 0.2492 - val_accuracy: 0.9000
# Epoch 13/20
# 207/207 [==============================] - 1s 7ms/step - loss: 0.2420 - accuracy: 0.9021 - val_loss: 0.2496 - val_accuracy: 0.8996
# Epoch 14/20
# 207/207 [==============================] - 1s 7ms/step - loss: 0.2384 - accuracy: 0.9043 - val_loss: 0.2495 - val_accuracy: 0.9013
# Epoch 15/20
# 207/207 [==============================] - 1s 7ms/step - loss: 0.2416 - accuracy: 0.9020 - val_loss: 0.2529 - val_accuracy: 0.8972
# Epoch 16/20
# 207/207 [==============================] - 1s 7ms/step - loss: 0.2439 - accuracy: 0.9043 - val_loss: 0.2492 - val_accuracy: 0.8983
# Epoch 17/20
# 207/207 [==============================] - 1s 7ms/step - loss: 0.2421 - accuracy: 0.8991 - val_loss: 0.2499 - val_accuracy: 0.8974
# Epoch 18/20
# 207/207 [==============================] - 1s 7ms/step - loss: 0.2338 - accuracy: 0.9044 - val_loss: 0.2523 - val_accuracy: 0.8963
# Epoch 19/20
# 207/207 [==============================] - 1s 7ms/step - loss: 0.2302 - accuracy: 0.9065 - val_loss: 0.2512 - val_accuracy: 0.8983
# Epoch 20/20
# 207/207 [==============================] - 2s 7ms/step - loss: 0.2319 - accuracy: 0.9050 - val_loss: 0.2510 - val_accuracy: 0.8970

# %%
plt.plot(history.history['accuracy'], 
         label='Доля верных ответов на обучающем наборе')
plt.plot(history.history['val_accuracy'], 
         label='Доля верных ответов на проверочном наборе')
plt.xlabel('Эпоха обучения')
plt.ylabel('Доля верных ответов')
plt.legend()
plt.show()

# %% [markdown]
# ## Готовим данные для LeaderBoard

# %%
sample_submission = pd.read_csv(KAGGLE_PATH + 'sample_supmission.csv', index_col='id')
sample_submission.label = model.predict_classes(x_test)
sample_submission.to_csv("sample_submission.csv")
